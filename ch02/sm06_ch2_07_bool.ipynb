# %% [markdown]
# #불 자료형이란?

# %% [markdown]
# 불(bool) 자료형이란 참(True)과 거짓(False)을 나타내는 자료형이다.
#
# 불 자료형은 다음 2가지 값만을 가질 수 있다.
#
# True - 참
#
# False - 거짓
#
# True나 False는 파이썬의 예약어로 true, false와 같이 사용하지 말고
#
# 첫 문자를 항상 대문자로 사용해야 한다.

# %%
a = True
b = False
type(a), type(b)
# Out:
# (bool, bool)

# %%
# 참과 거짓
print("1 == 1 --> ",1 == 1) 
print("2 > 1 --> ",2 > 1)
print("2 < 1 --> ",2 < 1) 
print("True + 1 --> ",True + 1)     #True 는 1
print("False + 1 --> ", False + 1)   #False 는 0
# Out:
# 1 == 1 -->  True
# 2 > 1 -->  True
# 2 < 1 -->  False
# True + 1 -->  2
# False + 1 -->  1

# %%
# 자료형의 참과 거짓
print('bool("python") --> ',bool("python"))
print('bool("") --> ',bool(""))
print('bool([1, 2, 3]) --> ',bool([1, 2, 3]))
print('bool([2, 3]) --> ',bool([2, 3]))
print('bool([]) --> ',bool([]))  #공백은 False
print('bool(()) --> ',bool(()))  #공백은 False 
print('bool({}) --> ',bool({}))  #공백은 False
print('bool(1) --> ',bool(1))   
print('bool(0) --> ',bool(0))   #0은 False
print('bool(None) --> ',bool(None))  #None값도 False
# Out:
# bool("python") -->  True
# bool("") -->  False
# bool([1, 2, 3]) -->  True
# bool([2, 3]) -->  True
# bool([]) -->  False
# bool(()) -->  False
# bool({}) -->  False
# bool(1) -->  True
# bool(0) -->  False
# bool(None) -->  False

# %%
# 불 값을 이용한 코드
a = [1, 2, 3, 4]
a
# Out:
# [1, 2, 3, 4]

# %%
while a:
    print(a.pop())
# Out:
# 4
# 3
# 2
# 1

# %%
if []:
    print("참")
else:
    print("거짓")
# Out:
# 거짓

# %%
############################
#  Representation error
## double precision representation of floating-point numbers
############################
1-0.9
# 0.09999999999999998
# Out:
# 0.09999999999999998

# %%
1-0.9==.1
# False
# Out:
# False

# %%
import decimal  # 외부모듈을 가져온다
x=decimal.Decimal(3.14)
y=decimal.Decimal(2.74)
x,y
# Out:
# (Decimal('3.140000000000000124344978758017532527446746826171875'),
#  Decimal('2.7400000000000002131628207280300557613372802734375'))

# %%
x*y
# Decimal('8.603600000000001010036498883')
# Out:
# Decimal('8.603600000000001010036498883')

# %%
decimal.getcontext().prec=4 #소수점4자리까지
x*y
# Decimal('8.604')
# Out:
# Decimal('8.604')
