# %% [markdown]
# #변수(variable)란?

# %%
# 변수는 자료(값)을 저장하는 공간이다.
a = [1, 2, 3]
id(a)  # a 변수가 가리키는 메모리의 주소
# Out:
# 140328738262152

# %%
# list
a = [1, 2, 3]
id(a)  # 주소가 다르다
# Out:
# 140328738319048

# %%
b = a
id(a), id(b)  #a,b가 같은 주소
# Out:
# (140328738319048, 140328738319048)

# %%
a is b
a[1] = 4
a, b
# Out:
# ([1, 4, 3], [1, 4, 3])

# %%
a is b
b = [1, 2, 3]
id(b)
# Out:
# 140328738262280

# %%
a is b
# Out:
# False

# %% [markdown]
# b 변수를 생성할 때 a 변수의 값을 가져오면서
#
# a와는 다른 주소를 가리키도록 만들수는 없을까?
#
# 다음 2가지 방법이 있다.

# %%
# 1. [:] 이용
a = [1, 2, 3]
b = a[:]
a[1] = 4
a, b
# Out:
# ([1, 4, 3], [1, 2, 3])

# %%
# 2. copy 모듈 이용
a = [1, 2, 3]

# %%
# from copy import copy
b = copy(a)  #값은 같으나 주소는 다르다
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9bfd715a8223> in <module>()
# ----> 1 b = copy(a)  #값은 같으나 주소는 다르다
#
# NameError: name 'copy' is not defined

# %%
b is a, a is b
# Out:
# (False, False)

# %%
# 변수를 만드는 여러 가지 방법
a, b = ("python", "life") #튜플 소괄호 없이 사용가능

# %%
a
# Out:
# 'python'

# %%
b
# Out:
# 'life'

# %%
a, b
# Out:
# ('python', 'life')

# %%
[a, b] = ["python", "life"] #리스트
a,b
# Out:
# ('python', 'life')

# %%
a = 3
b = 5

# %%
a, b = b, a   #a,b값이 바뀜
a,b
# Out:
# (5, 3)
